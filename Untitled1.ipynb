# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
path1="/content/drive/MyDrive/dataset/soil_data.csv"
df1=pd.read_csv(path1)
df1.head(5)

# %%
path2="/content/drive/MyDrive/Drought dataset/train_timeseries.csv"
df2=pd.read_csv(path2)
df2.head(5)

# %%
import pandas as pd
path3="/content/drive/MyDrive/dataset/validation_timeseries.csv"
df3=pd.read_csv(path3)
df3.head(5)
# Out:
#    fips        date  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# 0  1001  2017-01-01    32.50  100.02  10.47  14.69   14.47   14.47    17.68
# 1  1001  2017-01-02    63.52  100.04  12.75  17.96   17.75   17.75    20.30
# 2  1001  2017-01-03    18.82   99.69   9.74  14.24   13.44   13.44    18.48
# 3  1001  2017-01-04     0.01  100.02   5.21   8.10    3.86    3.88    11.74
# 4  1001  2017-01-05     0.01   99.89   4.54   5.91    2.20    2.22    13.07
#
#    T2M_MIN  ...     TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  WS50M  \
# 0    10.53  ...  14.63   2.14       2.71       1.52         1.19   4.40
# 1    16.14  ...  17.85   2.75       4.31       1.60         2.71   5.50
# 2     9.29  ...  14.06   2.25       3.73       1.64         2.09   4.80
# 3     2.12  ...   8.08   2.63       3.95       1.34         2.60   4.98
# 4    -0.18  ...   5.85   1.76       2.76       0.47         2.28   3.43
#
#    WS50M_MAX  WS50M_MIN  WS50M_RANGE  score
# ...

# %%
path4="/content/drive/MyDrive/dataset/test_timeseries.csv"
df4=pd.read_csv(path4)
df4.head(5)
# Out:
#    fips        date  PRECTOT      PS  QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# 0  1001  2019-01-01     2.25  100.51  9.69  14.71   13.55   13.52    17.38
# 1  1001  2019-01-02     4.94  100.48  8.65  13.05   11.83   11.74    17.76
# 2  1001  2019-01-03    20.74  100.03  8.59  12.12   11.67   11.67    13.74
# 3  1001  2019-01-04    16.17   99.47  7.93  11.80   10.38    9.59    18.19
# 4  1001  2019-01-05     0.01  100.39  5.32   7.91    4.73    4.71    14.37
#
#    T2M_MIN  ...     TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  WS50M  \
# 0    10.92  ...  14.63   1.20       1.50       0.79         0.71   2.74
# 1     9.54  ...  13.06   1.02       1.35       0.32         1.03   2.13
# 2    10.44  ...  12.12   1.83       4.23       0.34         3.88   3.41
# 3     5.44  ...  11.72   3.75       5.25       2.34         2.91   6.78
# 4     3.68  ...   7.75   2.32       2.90       1.69         1.21   4.42
#
#    WS50M_MAX  WS50M_MIN  WS50M_RANGE  score
# ...

# %%
print("Missing values in the soil  dataset:")
print(df1.isnull().sum())
# Out:
# Missing values in the validation  dataset:
# fips             0
# lat              0
# lon              0
# elevation        0
# slope1           0
# slope2           0
# slope3           0
# slope4           0
# slope5           0
# slope6           0
# slope7           0
# slope8           0
# aspectN          0
# aspectE          0
# aspectS          0
# aspectW          0
# aspectUnknown    0
# WAT_LAND         0
# NVG_LAND         0
# URB_LAND         0
# GRS_LAND         0
# FOR_LAND         0
# CULTRF_LAND      0
# CULTIR_LAND      0
# CULT_LAND        0
# SQ1              0
# SQ2              0
# SQ3              0
# SQ4              0
# SQ5              0
# SQ6              0
# SQ7              0
# dtype: int64

# %%
print("Missing values in the train dataset:")
print(df2.isnull().sum())
# Out:
# Missing values in the train dataset:
# fips                  0
# date                  0
# PRECTOT               0
# PS                    0
# QV2M                  0
# T2M                   0
# T2MDEW                0
# T2MWET                0
# T2M_MAX               0
# T2M_MIN               0
# T2M_RANGE             0
# TS                    0
# WS10M                 0
# WS10M_MAX             0
# WS10M_MIN             0
# WS10M_RANGE           0
# WS50M                 0
# WS50M_MAX             0
# WS50M_MIN             0
# WS50M_RANGE           0
# score          16543884
# dtype: int64

# %%
print("Missing values in the validation  dataset:")
print(df3.isnull().sum())

# %%
print("Missing values in the test dataset:")
print(df4.isnull().sum())
# Out:
# Missing values in the test dataset:
# fips                 0
# date                 0
# PRECTOT              0
# PS                   0
# QV2M                 0
# T2M                  0
# T2MDEW               0
# T2MWET               0
# T2M_MAX              0
# T2M_MIN              0
# T2M_RANGE            0
# TS                   0
# WS10M                0
# WS10M_MAX            0
# WS10M_MIN            0
# WS10M_RANGE          0
# WS50M                0
# WS50M_MAX            0
# WS50M_MIN            0
# WS50M_RANGE          0
# score          1945608
# dtype: int64

# %%
df1.dropna(inplace=True)
df2.dropna(inplace=True)
df3.dropna(inplace=True)
df4.dropna(inplace=True)

# %%
df1.drop_duplicates(inplace=True)
df2.drop_duplicates(inplace=True)
df3.drop_duplicates(inplace=True)
df4.drop_duplicates(inplace=True)

# %%
print("soil Dataset Information After Data Handling:")
print("Number of rows and columns:", df1.shape)
print("\nColumns in the soil dataset:")
print(df1.columns)
print("\nData types of columns:")
print(df1.dtypes)
print("\nSummary statistics:")
print(df1.describe())
print("\nPreview of the soil dataset:")
print(df1.head())
# Out:
# soil Dataset Information After Data Handling:
# Number of rows and columns: (3109, 32)
#
# Columns in the soil dataset:
# Index(['fips', 'lat', 'lon', 'elevation', 'slope1', 'slope2', 'slope3',
#        'slope4', 'slope5', 'slope6', 'slope7', 'slope8', 'aspectN', 'aspectE',
#        'aspectS', 'aspectW', 'aspectUnknown', 'WAT_LAND', 'NVG_LAND',
#        'URB_LAND', 'GRS_LAND', 'FOR_LAND', 'CULTRF_LAND', 'CULTIR_LAND',
#        'CULT_LAND', 'SQ1', 'SQ2', 'SQ3', 'SQ4', 'SQ5', 'SQ6', 'SQ7'],
#       dtype='object')
#
# Data types of columns:
# fips               int64
# lat              float64
# lon              float64
# elevation          int64
# slope1           float64
# slope2           float64
# slope3           float64
# slope4           float64
# slope5           float64
# slope6           float64
# slope7           float64
# slope8           float64
# aspectN          float64
# aspectE          float64
# aspectS          float64
# aspectW          float64
# ...

# %%
print("Train Dataset Information After Data Handling:")
print("Number of rows and columns:", df2.shape)
print("\nColumns in the Train dataset:")
print(df2.columns)
print("\nData types of columns:")
print(df2.dtypes)
print("\nSummary statistics:")
print(df2.describe())
print("\nPreview of the Train dataset:")
print(df2.head())
# Out:
# Train Dataset Information After Data Handling:
# Number of rows and columns: (2756796, 21)
#
# Columns in the Train dataset:
# Index(['fips', 'date', 'PRECTOT', 'PS', 'QV2M', 'T2M', 'T2MDEW', 'T2MWET',
#        'T2M_MAX', 'T2M_MIN', 'T2M_RANGE', 'TS', 'WS10M', 'WS10M_MAX',
#        'WS10M_MIN', 'WS10M_RANGE', 'WS50M', 'WS50M_MAX', 'WS50M_MIN',
#        'WS50M_RANGE', 'score'],
#       dtype='object')
#
# Data types of columns:
# fips             int64
# date            object
# PRECTOT        float64
# PS             float64
# QV2M           float64
# T2M            float64
# T2MDEW         float64
# T2MWET         float64
# T2M_MAX        float64
# T2M_MIN        float64
# T2M_RANGE      float64
# TS             float64
# WS10M          float64
# WS10M_MAX      float64
# WS10M_MIN      float64
# WS10M_RANGE    float64
# WS50M          float64
# WS50M_MAX      float64
# WS50M_MIN      float64
# WS50M_RANGE    float64
# score          float64
# dtype: object
#
# Summary statistics:
# ...

# %%
print("validation Dataset Information After Data Handling:")
print("Number of rows and columns:", df3.shape)
print("\nColumns in the Train dataset:")
print(df3.columns)
print("\nData types of columns:")
print(df3.dtypes)
print("\nSummary statistics:")
print(df3.describe())
print("\nPreview of the Train dataset:")
print(df3.head())
# Out:
# validation Dataset Information After Data Handling:
# Number of rows and columns: (323232, 21)
#
# Columns in the Train dataset:
# Index(['fips', 'date', 'PRECTOT', 'PS', 'QV2M', 'T2M', 'T2MDEW', 'T2MWET',
#        'T2M_MAX', 'T2M_MIN', 'T2M_RANGE', 'TS', 'WS10M', 'WS10M_MAX',
#        'WS10M_MIN', 'WS10M_RANGE', 'WS50M', 'WS50M_MAX', 'WS50M_MIN',
#        'WS50M_RANGE', 'score'],
#       dtype='object')
#
# Data types of columns:
# fips             int64
# date            object
# PRECTOT        float64
# PS             float64
# QV2M           float64
# T2M            float64
# T2MDEW         float64
# T2MWET         float64
# T2M_MAX        float64
# T2M_MIN        float64
# T2M_RANGE      float64
# TS             float64
# WS10M          float64
# WS10M_MAX      float64
# WS10M_MIN      float64
# WS10M_RANGE    float64
# WS50M          float64
# WS50M_MAX      float64
# WS50M_MIN      float64
# WS50M_RANGE    float64
# score          float64
# dtype: object
#
# ...

# %%
print("test Dataset Information After Data Handling:")
print("Number of rows and columns:", df4.shape)
print("\nColumns in the Train dataset:")
print(df4.columns)
print("\nData types of columns:")
print(df4.dtypes)
print("\nSummary statistics:")
print(df4.describe())
print("\nPreview of the Train dataset:")
print(df4.head())
# Out:
# test Dataset Information After Data Handling:
# Number of rows and columns: (326340, 21)
#
# Columns in the Train dataset:
# Index(['fips', 'date', 'PRECTOT', 'PS', 'QV2M', 'T2M', 'T2MDEW', 'T2MWET',
#        'T2M_MAX', 'T2M_MIN', 'T2M_RANGE', 'TS', 'WS10M', 'WS10M_MAX',
#        'WS10M_MIN', 'WS10M_RANGE', 'WS50M', 'WS50M_MAX', 'WS50M_MIN',
#        'WS50M_RANGE', 'score'],
#       dtype='object')
#
# Data types of columns:
# fips             int64
# date            object
# PRECTOT        float64
# PS             float64
# QV2M           float64
# T2M            float64
# T2MDEW         float64
# T2MWET         float64
# T2M_MAX        float64
# T2M_MIN        float64
# T2M_RANGE      float64
# TS             float64
# WS10M          float64
# WS10M_MAX      float64
# WS10M_MIN      float64
# WS10M_RANGE    float64
# WS50M          float64
# WS50M_MAX      float64
# WS50M_MIN      float64
# WS50M_RANGE    float64
# score          float64
# dtype: object
#
# Summary statistics:
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as plt
import numpy as np
import warnings

from itertools import zip_longest
from sklearn.datasets import make_classification
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn.covariance import EllipticEnvelope
from sklearn.cluster import DBSCAN
from sklearn.model_selection import train_test_split
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, mean_absolute_error

warnings.filterwarnings("ignore")

# %%
# Correlation matrix
corr_matrix =df2.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-30-c69e85546a26>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix =df2.corr()

# %%
corr_matrix =df2.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
# <ipython-input-32-50201af024f9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix =df2.corr()

# %%
corr_matrix =df2.corr()
plt.figure(figsize=(12, 10))

# Create a heatmap with annotations and a color map
heatmap = sns.heatmap(corr_matrix, annot=True, cmap='green')

# Highlight cells with correlations above 0.75 or below -0.75
for i in range(len(corr_matrix.columns)):
    for j in range(len(corr_matrix.columns)):
        if i != j and (corr_matrix.iloc[i, j] > 0.75 or corr_matrix.iloc[i, j] < -0.75):
            heatmap.text(j + 0.5, i + 0.5, f"{corr_matrix.iloc[i, j]:.2f}",
                         ha='center', va='center', color='white', fontsize=8)

# Set the title of the heatmap
plt.title('Correlation Matrix Heatmap')

# Show the plot
plt.show()

# %%
corr_matrix = df2.corr()

filtered_correlations = corr_matrix[(corr_matrix <= -0.75) | (corr_matrix >= 0.75)]

plt.figure(figsize=(9, 6))
sns.heatmap(filtered_correlations, annot=True, cmap='Greens', center=0)
plt.title("Correlation Heatmap (Correlations above -0.75 and 0.75)")
plt.show()
# Out:
# <ipython-input-18-fb5206fd051d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df2.corr()

# %%
import pandas as pd
path2="/content/drive/MyDrive/dataset/train_timeseries.csv"
df2=pd.read_csv(path2)

# %%
corr_matrix_QV2M =df2.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix_QV2M, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix ON Specific Humidity at 2 Meters (g/kg)')
QV2M=df2.loc[df2.Category=="Specific Humidity at 2 Meters (g/kg)"]
plt.show()
# Out:
# <ipython-input-12-66f2ef6f7fc9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix_QV2M =df2.corr()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-66f2ef6f7fc9> in <cell line: 5>()
#       3 sns.heatmap(corr_matrix_QV2M, annot=True, cmap='coolwarm')
#       4 plt.title('Correlation Matrix ON Specific Humidity at 2 Meters (g/kg)')
# ----> 5 QV2M=df2.loc[df2.Category=="Specific Humidity at 2 Meters (g/kg)"]
#       6 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
# ...

# %%
corr_matrix_QV2M = df2.corr()

# Create a heatmap for the entire correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix_QV2M, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix ON Specific Humidity at 2 Meters (g/kg)')

# Show the correlation matrix heatmap
plt.show()

# Filter the DataFrame to include only rows where 'Category' is 'Specific Humidity at 2 Meters (g/kg)'
QV2M = df2[df2['QV2M'] == 'Specific Humidity at 2 Meters (g/kg)']

# Display the filtered DataFrame
print(QV2M)
# Out:
# <ipython-input-14-11b27eeab0f7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix_QV2M = df2.corr()
# Empty DataFrame
# Columns: [fips, date, PRECTOT, PS, QV2M, T2M, T2MDEW, T2MWET, T2M_MAX, T2M_MIN, T2M_RANGE, TS, WS10M, WS10M_MAX, WS10M_MIN, WS10M_RANGE, WS50M, WS50M_MAX, WS50M_MIN, WS50M_RANGE, score]
# Index: []
#
# [0 rows x 21 columns]

# %%
corr_matrix_T2M = df2.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix_T2M, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix ON Temperature at 2 Meters (T2M)')
plt.show()
T2M = df2[df2['T2M_MAX'] == 'Temperature at 2 Meters (T2M)']
print(T2M)
# Out:
# <ipython-input-16-eea764af1214>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix_T2M = df2.corr()
# Empty DataFrame
# Columns: [fips, date, PRECTOT, PS, QV2M, T2M, T2MDEW, T2MWET, T2M_MAX, T2M_MIN, T2M_RANGE, TS, WS10M, WS10M_MAX, WS10M_MIN, WS10M_RANGE, WS50M, WS50M_MAX, WS50M_MIN, WS50M_RANGE, score]
# Index: []
#
# [0 rows x 21 columns]

# %%
corr_matrix_PRECTOT = df2.corr()

# Create a heatmap for the entire correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix_PRECTOT, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix ON Precipitation (mm day-1)')

# Show the correlation matrix heatmap
plt.show()

# Filter the DataFrame to include only rows where 'Category' is 'Precipitation (mm day-1)'
PRECTOT = df2[df2['PRECTOT'] == 'Precipitation (mm day-1)']

# Display the filtered DataFrame
print(PRECTOT)
# Out:
# <ipython-input-19-d5c61c5809ef>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix_PRECTOT = df2.corr()
# Empty DataFrame
# Columns: [fips, date, PRECTOT, PS, QV2M, T2M, T2MDEW, T2MWET, T2M_MAX, T2M_MIN, T2M_RANGE, TS, WS10M, WS10M_MAX, WS10M_MIN, WS10M_RANGE, WS50M, WS50M_MAX, WS50M_MIN, WS50M_RANGE, score]
# Index: []
#
# [0 rows x 21 columns]

# %%
#Distribution of all the continuous variables
column_list = ['PRECTOT','PS','QV2M','T2M','T2MDEW','T2MWET','T2M_MAX','T2M_MIN','T2M_RANGE','TS','WS10M','WS10M_MAX','WS10M_MIN','WS10M_RANGE','WS50M','WS50M_MAX','WS50M_MIN','WS50M_RANGE']
new_df2_ts = df2[column_list]

# Iterate over each continuous variable and create a histogram
for col_name in column_list:
    plt.figure()  # Create a new figure for each variable
    plt.hist(new_df2_ts[col_name], density=True, color='red')  # Plot the histogram
    x_name = col_name  # Set the x-axis label
    plt.xlabel(x_name)
    y_name = 'Density'  # Set the y-axis label
    plt.ylabel(y_name)
    plt.title(f'Distribution of {x_name}')  # Set the title of the histogram

# Show the histograms
plt.show()

# %%
plt.scatter(df2['QV2M'],df2['T2M_MAX'], c =df2['score'])
plt.xlabel('QV2M')
plt.ylabel('T2M_MAX')
plt.title('Variation of T2M_MAX vs QV2M')
plt.show()

# %%
plt.scatter(df2['PRECTOT'], df2['T2MDEW'], c =df2['score'])
plt.xlabel('PRECTOT')
plt.ylabel('T2MDEW')
plt.title('Variation of T2MDEW vs PRECTOT')
plt.show()

# %%
# Scatter plot of 'WS50M' vs 'T2M' color-coded by 'score'
plt.scatter(df2['WS50M'], df2['T2M'], c=df2['score'])
plt.xlabel('WS50M')
plt.ylabel('T2M')
plt.title('Variation of T2M vs WS50M')
plt.show()

# %%
# Scatter plot of 'T2MDEW' vs 'T2M'
plt.scatter(df2['T2MDEW'], df2['T2M'], c=df2['score'])
plt.xlabel('T2MDEW')
plt.ylabel('T2M')
plt.title('Variation of T2M vs T2MDEW')
plt.show()

# %%
import matplotlib.pyplot as plt
df2['date'] = pd.to_datetime(df2['date'])

plt.figure(figsize=(12, 6))
plt.hist(df2['date'], df2['score'], color='blue')
plt.title('Time Series Data - Score')
plt.xlabel('Date')
plt.ylabel('Score')
plt.show()

# %%
lag = 7
plt.figure(figsize=(10, 6))
plt.scatter(df2['score'].shift(lag), df2['score'], alpha=0.5, color='blue')
plt.title(f'Lagged Scatter Plot (Lag={lag})')
plt.xlabel(f'Score(t-{lag})')
plt.ylabel('Score(t)')
plt.show()

# %%
plt.figure(figsize=(8, 6))
df2['score'].hist(bins=30, color='red')
plt.title('Distribution of Scores in df2')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Calculating skewness for each feature in df2
skewness_df2 = df2.skew(axis=0, skipna=True)
feature_names_df2 = skewness_df2.index.tolist()
skewness_values_df2 = skewness_df2.tolist()

print("\nSkewness: \n", skewness_df2)
# Create a horizontal barplot for skewness
plt.figure(figsize=(10, 6))
plt.barh(feature_names_df2, skewness_values_df2, color='red')
plt.xlabel('Skewness')
plt.ylabel('Feature Names')
plt.title('Skewness of Features in df2')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-16-f01f92aa8f18>:2: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   skewness_df2 = df2.skew(axis=0, skipna=True)
# Skewness:
#  fips          -0.077367
# PRECTOT        4.978126
# PS            -2.133676
# QV2M           0.541653
# T2M           -0.401920
# T2MDEW        -0.283064
# T2MWET        -0.268606
# T2M_MAX       -0.448358
# T2M_MIN       -0.340570
# T2M_RANGE      0.075695
# TS            -0.372514
# WS10M          1.125060
# WS10M_MAX      0.961933
# WS10M_MIN      1.393141
# WS10M_RANGE    1.326772
# WS50M          0.889572
# WS50M_MAX      0.943523
# WS50M_MIN      0.869509
# WS50M_RANGE    1.238826
# score          1.502973
# dtype: float64

# %%
# Calculate kurtosis for each feature in df2
kurtosis_df2 = df2.kurtosis(axis=0, skipna=True)
feature_names_df2 = kurtosis_df2.index.tolist()
kurtosis_values_df2 = kurtosis_df2.tolist()

print("\nKurtosis: \n", kurtosis_df2)

# Create a horizontal bar plot for kurtosis
plt.figure(figsize=(10, 6))
sns.barplot(x=kurtosis_values_df2, y=feature_names_df2, palette='coolwarm')
plt.title('Kurtosis Plot for df2')
plt.xlabel('Kurtosis Value')
plt.ylabel('Features')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-6-e840799ded44>:2: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   kurtosis_df2 = df2.kurtosis(axis=0, skipna=True)
# Kurtosis:
#  fips           -1.100136
# PRECTOT        42.614717
# PS              4.814345
# QV2M           -0.771495
# T2M            -0.573215
# T2MDEW         -0.736467
# T2MWET         -0.764353
# T2M_MAX        -0.510855
# T2M_MIN        -0.472496
# T2M_RANGE      -0.323873
# TS             -0.555780
# WS10M           1.433580
# WS10M_MAX       0.800935
# WS10M_MIN       3.090438
# WS10M_RANGE     2.256303
# WS50M           0.880366
# WS50M_MAX       1.136298
# WS50M_MIN       0.626247
# WS50M_RANGE     2.349057
# score           1.392799
# dtype: float64

# %% [markdown]
# Model creation:

# %%
models = [
    ('Isolation Forest', IsolationForest(contamination=0.05, random_state=10)),
    ('Local Outlier Factor', LocalOutlierFactor(contamination=0.05)),
    ('One-Class SVM', OneClassSVM(nu=0.05)),
    ('Elliptic Envelope', EllipticEnvelope(contamination=0.05)),
    ('DBSCAN', DBSCAN(eps=0.5, min_samples=5))
]

threshold = 2.5

outlier_indices = {}

for name, model in models:
    if name == 'DBSCAN':
        labels = model.fit_predict(df2.drop(columns=['date', 'score']))
        scores = -labels  # Using labels for DBSCAN (DBSCAN doesn't have negative_outlier_factor_)
    else:
        scores = model.fit_predict(df2.drop(columns=['date', 'score']))
        scores = -scores
    outlier_indices[name] = df2.index[scores > threshold]

all_outlier_indices = np.concatenate(list(outlier_indices.values()))

data_without_outliers = df2.drop(index=all_outlier_indices)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
